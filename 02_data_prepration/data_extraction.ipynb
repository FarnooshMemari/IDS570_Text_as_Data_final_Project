# %% [markdown]
# # Sentence Corpus Construction
#
# ## Overview
# This notebook builds a sentence-level corpus from validated source URLs for health equity analysis. It reads source metadata, retrieves content from PDF and HTML documents, extracts clean text, and generates analysis-ready sentence outputs.
#
# The objective of this notebook is to produce a high-quality, traceable text corpus with clear quality-control artifacts before downstream modeling and inference.
#
# ## Objectives
# - Inspect and load validated source records
# - Fetch source content reliably with retry and timeout safeguards
# - Extract text from PDF and HTML sources using consistent parsing logic
# - Segment cleaned text into sentence-level observations
# - Generate corpus outputs for full and equity-focused analyses
# - Produce quality-control, exclusion, and failure logs for auditability
#
# ## Dataset Description
# The workflow starts from `validated_dataset.csv`, where each row represents a source document linked to a project record. The notebook processes each source, applies extraction rules, and writes sentence-level outputs plus supporting logs in the working directory.
#
# Core outputs include `full_sentence_corpus.csv`, `equity_sentence_subset.csv`, `extraction_qc_report.csv`, `exclusion_log.csv`, and `failure_log.csv`.
#
# ## Key Considerations
# - Source links may fail intermittently due to network or host constraints
# - PDF/HTML format differences can affect extraction consistency
# - Very short, very long, or noisy sentences can reduce downstream quality
# - Some documents may be excluded due to page limits or parse failures
# - Reproducible document and sentence identifiers are required for traceability
#
# ## Outcome
# The resulting corpus and logs provide a transparent foundation for subsequent text analysis, feature engineering, and model development.

# %% [markdown]
# # Sentence-Level Corpus Builder — Health Equity Text Analysis
# ### IDS 570: Text as Data — Final Project
#
# This notebook reads `validated_dataset.csv`, fetches every source URL, extracts and cleans text, segments it into sentences with spaCy, and writes all outputs to **../01_data/raw_data/**.
#
# **Outputs produced (written to ../01_data/raw_data/):**
# - `full_sentence_corpus.csv`
# - `equity_sentence_subset.csv`
# - `extraction_qc_report.csv`
# - `exclusion_log.csv`
# - `failure_log.csv`
# - `corpus_build.log`

# %%
# ── Install dependencies (run once) ──────────────────────────
# !pip install pandas requests beautifulsoup4 pdfplumber spacy -q
# !python -m spacy download en_core_web_sm -q
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# ── Imports & configuration ──────────────────────────────────
import csv, hashlib, io, logging, os, re, sys, time, traceback
from collections import Counter
from pathlib import Path
from typing import Optional

import pandas as pd
import requests
import spacy
from bs4 import BeautifulSoup

try:
    import pdfplumber

    PDF_BACKEND = "pdfplumber"
except ImportError:
    from pypdf import PdfReader

    PDF_BACKEND = "pypdf"

# ── All outputs go to 01_data/raw_data folder ────────────────
OUTPUT_DIR = Path("../01_data/raw_data")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# ── Page-count filter thresholds ─────────────────────────────
MIN_PAGES = 20
MAX_PAGES = 150

# ── Request settings ─────────────────────────────────────────
REQUEST_TIMEOUT = 60
RETRY_ATTEMPTS = 2
RETRY_DELAY = 5

# ── Sentence quality thresholds ──────────────────────────────
MIN_SENTENCE_CHARS = 20
MAX_SENTENCE_CHARS = 3000

USER_AGENT = (
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
    "AppleWebKit/537.36 (KHTML, like Gecko) "
    "Chrome/124.0.0.0 Safari/537.36"
)

# ── Logging ──────────────────────────────────────────────────
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s  %(levelname)-8s  %(message)s",
    handlers=[
        logging.StreamHandler(sys.stdout),
        logging.FileHandler(
            OUTPUT_DIR / "corpus_build.log", mode="w", encoding="utf-8"
        ),
    ],
)
log = logging.getLogger("corpus_builder")

print(f"PDF backend : {PDF_BACKEND}")
print(f"Output dir  : {OUTPUT_DIR.resolve()}")
# Out:
# PDF backend : pdfplumber
# Output dir  : /Users/sebinescaria/Downloads/Text as Data - Final project materials/Final project/IDS570_Text_as_Data_final_Project/01_data/raw_data

# %%
# ── Load spaCy model ─────────────────────────────────────────
NLP = spacy.load("en_core_web_sm")
NLP.max_length = 5_000_000
print(f"spaCy model loaded: {NLP.meta['name']} v{NLP.meta['version']}")
# Out:
# spaCy model loaded: core_web_sm v3.8.0

# %% [markdown]
# ## Helper functions

# %%
# ── Helpers ──────────────────────────────────────────────────


def make_document_id(url: str) -> str:
    """Deterministic short hash — same URL always gets the same id."""
    return "doc_" + hashlib.sha256(url.encode()).hexdigest()[:12]


def detect_source_type(url: str) -> str:
    """Heuristic: PDF vs HTML based on URL extension."""
    lower = url.lower().split("?")[0].split("#")[0]
    return "pdf" if lower.endswith(".pdf") else "html"


def fetch_content(url: str) -> requests.Response:
    """GET with retries, timeout, and realistic User-Agent."""
    headers = {"User-Agent": USER_AGENT}
    for attempt in range(1, RETRY_ATTEMPTS + 1):
        try:
            resp = requests.get(
                url, headers=headers, timeout=REQUEST_TIMEOUT, allow_redirects=True
            )
            resp.raise_for_status()
            return resp
        except Exception as exc:
            log.warning(
                "Attempt %d/%d failed for %s: %s", attempt, RETRY_ATTEMPTS, url, exc
            )
            if attempt < RETRY_ATTEMPTS:
                time.sleep(RETRY_DELAY)
    raise RuntimeError(f"All {RETRY_ATTEMPTS} attempts failed for {url}")


print("Helpers defined ✓")
# Out:
# Helpers defined ✓

# %% [markdown]
# ## PDF extraction

# %%
# ── PDF extraction ───────────────────────────────────────────


def get_pdf_page_count(content_bytes: bytes) -> Optional[int]:
    """Return number of pages, or None if unreadable."""
    try:
        if PDF_BACKEND == "pdfplumber":
            with pdfplumber.open(io.BytesIO(content_bytes)) as pdf:
                return len(pdf.pages)
        else:
            reader = PdfReader(io.BytesIO(content_bytes))
            return len(reader.pages)
    except Exception:
        return None


def extract_pdf_text(content_bytes: bytes) -> str:
    """Extract readable text from all pages of a PDF."""
    pages_text = []
    try:
        if PDF_BACKEND == "pdfplumber":
            with pdfplumber.open(io.BytesIO(content_bytes)) as pdf:
                for page in pdf.pages:
                    txt = page.extract_text() or ""
                    pages_text.append(txt)
        else:
            reader = PdfReader(io.BytesIO(content_bytes))
            for page in reader.pages:
                txt = page.extract_text() or ""
                pages_text.append(txt)
    except Exception as exc:
        log.error("PDF text extraction error: %s", exc)
    return "\n".join(pages_text)


print("PDF extraction defined ✓")
# Out:
# PDF extraction defined ✓

# %% [markdown]
# ## HTML extraction (with PubMed abstract handling)

# %%
# ── HTML extraction ──────────────────────────────────────────


def extract_html_text(html: str, url: str) -> str:
    """
    Extract main-body text from an HTML page.
    PubMed pages → abstract only.
    """
    soup = BeautifulSoup(html, "html.parser")

    # Remove boilerplate tags
    for tag in soup.find_all(
        [
            "nav",
            "header",
            "footer",
            "aside",
            "script",
            "style",
            "noscript",
            "iframe",
            "form",
            "button",
            "svg",
        ]
    ):
        tag.decompose()

    # Remove boilerplate by class / id patterns
    bp = re.compile(
        r"(cookie|consent|banner|sidebar|menu|nav|footer|advertisement|"
        r"popup|modal|social[-_]?share|related[-_]?articles|comment|"
        r"newsletter|signup)",
        re.I,
    )
    for el in soup.find_all(True, {"class": bp}):
        el.decompose()
    for el in soup.find_all(True, {"id": bp}):
        el.decompose()

    # ── PubMed special handling ──
    is_pubmed = "pubmed.ncbi.nlm.nih.gov" in url or "ncbi.nlm.nih.gov/pubmed" in url
    if is_pubmed:
        return _extract_pubmed_abstract(soup)

    # ── Generic: prefer <main> or <article> ──
    main = soup.find("main") or soup.find("article")
    if main:
        return main.get_text(separator="\n", strip=True)

    body = soup.find("body")
    if body:
        return body.get_text(separator="\n", strip=True)
    return soup.get_text(separator="\n", strip=True)


def _extract_pubmed_abstract(soup: BeautifulSoup) -> str:
    """Extract ONLY the abstract from a PubMed page."""
    abstract_div = soup.find("div", class_=re.compile(r"abstract", re.I))
    if abstract_div:
        return abstract_div.get_text(separator="\n", strip=True)

    abstract_tag = soup.find("abstract")
    if abstract_tag:
        return abstract_tag.get_text(separator="\n", strip=True)

    for heading in soup.find_all(["h2", "h3", "h4"]):
        if "abstract" in heading.get_text(strip=True).lower():
            parts = []
            for sib in heading.find_next_siblings():
                if sib.name and sib.name.startswith("h"):
                    break
                parts.append(sib.get_text(separator=" ", strip=True))
            if parts:
                return "\n".join(parts)
    return ""


print("HTML extraction defined ✓")
# Out:
# HTML extraction defined ✓

# %% [markdown]
# ## Text cleaning

# %%
# ── Text cleaning ────────────────────────────────────────────

_RE_PAGE_NUMBERS = re.compile(r"^\s*\d{1,4}\s*$", re.MULTILINE)
_RE_DOT_LEADERS = re.compile(r"\.{4,}")
_RE_OCR_SPACED = re.compile(r"(?:[A-Z]\s){3,}[A-Z]")
_RE_MULTI_SPACE = re.compile(r"[ \t]{2,}")
_RE_MULTI_NEWLINE = re.compile(r"\n{3,}")
_RE_HEADER_FOOTER = re.compile(
    r"(?i)^.{0,5}(page\s+\d+|www\.|http|©|all rights reserved|"
    r"table of contents|acknowledgments?).{0,80}$",
    re.MULTILINE,
)


def clean_text(raw: str) -> str:
    """Normalize and clean extracted text."""
    if not raw:
        return ""
    text = raw

    # Fix encoding artifacts
    for old, new in [
        ("\u00a0", " "),
        ("\u2019", "'"),
        ("\u2018", "'"),
        ("\u201c", '"'),
        ("\u201d", '"'),
        ("\u2013", "–"),
        ("\u2014", "—"),
        ("\uf0b7", ""),
        ("\x0c", "\n"),
    ]:
        text = text.replace(old, new)

    # Remove noise patterns
    text = _RE_PAGE_NUMBERS.sub("", text)
    text = _RE_DOT_LEADERS.sub("", text)
    text = _RE_OCR_SPACED.sub("", text)
    text = _RE_HEADER_FOOTER.sub("", text)

    # Normalize whitespace
    text = _RE_MULTI_SPACE.sub(" ", text)
    text = _RE_MULTI_NEWLINE.sub("\n\n", text)

    # Remove duplicate lines (keep first occurrence)
    seen = set()
    deduped = []
    for line in text.split("\n"):
        stripped = line.strip()
        if stripped and stripped not in seen:
            seen.add(stripped)
            deduped.append(stripped)
        elif not stripped:
            deduped.append("")
    return "\n".join(deduped).strip()


print("Text cleaning defined ✓")
# Out:
# Text cleaning defined ✓

# %% [markdown]
# ## Sentence segmentation & quality filter

# %%
# ── Sentence segmentation & filtering ────────────────────────

_RE_ALL_CAPS_LINE = re.compile(r"^[A-Z\s\d\W]{5,}$")
_RE_TOC_LINE = re.compile(r"^\d+[\.\)]\s")
_RE_HEADING_LIKE = re.compile(r"^(chapter|section|appendix|figure|table)\s", re.I)


def is_valid_sentence(text: str) -> bool:
    """Return True if text looks like a real English sentence."""
    t = text.strip()
    if len(t) < MIN_SENTENCE_CHARS or len(t) > MAX_SENTENCE_CHARS:
        return False
    if _RE_ALL_CAPS_LINE.match(t):
        return False
    if _RE_TOC_LINE.match(t):
        return False
    if _RE_HEADING_LIKE.match(t):
        return False
    if not re.search(r"[a-z]", t):
        return False
    words = [w for w in t.split() if re.search(r"[a-zA-Z]", w)]
    if len(words) < 3:
        return False
    return True


def segment_sentences(cleaned: str) -> list:
    """Use spaCy to split text into sentences, then filter."""
    if not cleaned:
        return []
    doc = NLP(cleaned)
    sentences = []
    for sent in doc.sents:
        s = sent.text.strip()
        s = re.sub(r"\s*\n\s*", " ", s)
        s = re.sub(r"\s{2,}", " ", s)
        if is_valid_sentence(s):
            sentences.append(s)
    return sentences


print("Sentence segmentation defined ✓")
# Out:
# Sentence segmentation defined ✓

# %% [markdown]
# ## Feature columns (equity flags, related terms, definitions)

# %%
# ── Feature columns ──────────────────────────────────────────

_RE_EQUITY = re.compile(r"\bequity\b", re.I)
_RE_EQUITIES = re.compile(r"\bequities\b", re.I)
_RE_HEALTH_EQUITY = re.compile(r"\bhealth\s+equity\b", re.I)

_RELATED_TERMS = re.compile(
    r"\b(disparit(?:y|ies)|inequalit(?:y|ies)|access|underserved|"
    r"social\s+determinants?|sdoh)\b",
    re.I,
)

_DEFINITION_PATTERNS = [
    re.compile(r"\b(?:is|are)\s+defined\s+as\b", re.I),
    re.compile(r"\b(?:refers?\s+to|meaning|means)\b", re.I),
    re.compile(r"\bequity\s+(?:is|means|refers)\b", re.I),
    re.compile(r"\bdefine[sd]?\s+(?:health\s+)?equity\b", re.I),
    re.compile(r"\bhealth\s+equity\s+is\b", re.I),
    re.compile(r"\bwe\s+define\b", re.I),
]


def compute_features(sentence: str) -> dict:
    """Compute all per-sentence feature columns."""
    contains_equity = bool(_RE_EQUITY.search(sentence))
    contains_equities = bool(_RE_EQUITIES.search(sentence))
    contains_health_equity = bool(_RE_HEALTH_EQUITY.search(sentence))
    contains_related = bool(_RELATED_TERMS.search(sentence))
    is_def = any(p.search(sentence) for p in _DEFINITION_PATTERNS)
    tokens = sentence.split()

    return {
        "contains_equity": contains_equity,
        "contains_equities": contains_equities,
        "contains_health_equity": contains_health_equity,
        "contains_related_terms": contains_related,
        "is_definition_sentence": is_def,
        "word_count": len(tokens),
        "char_count": len(sentence),
        "sentence_length_tokens": len(tokens),
    }


print("Feature columns defined ✓")
# Out:
# Feature columns defined ✓

# %% [markdown]
# ## Document subtype classification (rule-based)

# %%
# ── Document subtype heuristic ────────────────────────────────


def classify_subtype(title: str, category: str, text_sample: str) -> str:
    """
    Rule-based classification:
      conceptual | empirical | policy_report | commentary
    """
    t = (title + " " + text_sample[:2000]).lower()

    if category == "news_commentary":
        return "commentary"
    if category in ("federal_policy", "state_local"):
        return "policy_report"

    empirical_kw = [
        "method",
        "result",
        "findings",
        "sample",
        "regression",
        "survey",
        "cohort",
        "trial",
        "odds ratio",
        "p-value",
        "participants",
        "cross-sectional",
        "longitudinal",
        "data were",
        "data was",
        "n =",
        "n=",
    ]
    conceptual_kw = [
        "concept",
        "framework",
        "theory",
        "definition",
        "conceptual",
        "normative",
        "discourse",
        "philosophical",
        "scoping review",
        "narrative review",
        "meta-narrative",
    ]
    commentary_kw = [
        "editorial",
        "commentary",
        "perspective",
        "opinion",
        "viewpoint",
        "letter to",
    ]

    scores = {
        "empirical": sum(1 for kw in empirical_kw if kw in t),
        "conceptual": sum(1 for kw in conceptual_kw if kw in t),
        "commentary": sum(1 for kw in commentary_kw if kw in t),
    }
    best = max(scores, key=scores.get)
    if scores[best] == 0:
        return "policy_report" if category == "ngo_nonprofit" else "conceptual"
    return best


print("Subtype classifier defined ✓")
# Out:
# Subtype classifier defined ✓

# %% [markdown]
# ## Single-source processing function

# %%
# ── Process one source ────────────────────────────────────────


def process_one_source(row: dict) -> dict:
    """
    Fetch → extract → clean → segment one source.
    Returns dict with status, page_count, sentences, etc.
    """
    url = row["url"]
    title = row["title"]
    category = row["category"]
    source_type = detect_source_type(url)

    result = {
        "url": url,
        "title": title,
        "category": category,
        "source_label": row.get("source_label", ""),
        "source_type": source_type,
        "page_count": None,
        "sentences": [],
        "exclusion_reason": None,
        "status": "success",
        "notes": "",
        "raw_text_sample": "",
    }

    # ── Fetch ──
    try:
        resp = fetch_content(url)
    except Exception as exc:
        result["status"] = "fetch_failed"
        result["notes"] = str(exc)
        return result

    content_type = resp.headers.get("Content-Type", "").lower()
    if "application/pdf" in content_type:
        source_type = "pdf"
        result["source_type"] = "pdf"

    # ── PDF path ──
    if source_type == "pdf":
        content_bytes = resp.content
        page_count = get_pdf_page_count(content_bytes)
        result["page_count"] = page_count

        if page_count is None:
            result["status"] = "failed"
            result["notes"] = "Could not determine PDF page count"
            return result

        if page_count < MIN_PAGES:
            result["status"] = "excluded"
            result["exclusion_reason"] = f"page_count={page_count} < {MIN_PAGES}"
            return result
        if page_count > MAX_PAGES:
            result["status"] = "excluded"
            result["exclusion_reason"] = f"page_count={page_count} > {MAX_PAGES}"
            return result

        raw_text = extract_pdf_text(content_bytes)

    # ── HTML path ──
    else:
        raw_text = extract_html_text(resp.text, url)
        result["page_count"] = None

    if not raw_text or len(raw_text.strip()) < 50:
        result["status"] = "failed"
        result["notes"] = "No meaningful text extracted"
        return result

    # ── Clean → segment ──
    cleaned = clean_text(raw_text)
    result["raw_text_sample"] = cleaned[:500]
    result["sentences"] = segment_sentences(cleaned)

    if not result["sentences"]:
        result["status"] = "failed"
        result["notes"] = "No valid sentences after segmentation"

    return result


print("Source processor defined ✓")
# Out:
# Source processor defined ✓

# %% [markdown]
# ## Main pipeline — process all sources & write outputs
#
# > **Runtime note:** This cell fetches 221 URLs sequentially with a 0.5 s delay between requests. Expect **15–30 minutes** depending on network speed and server responsiveness. Progress is printed after each source.

# %%
# ── MAIN PIPELINE ────────────────────────────────────────────

INPUT_CSV = "../01_data/validated_dataset.csv"

df_sources = pd.read_csv(INPUT_CSV)
total_sources = len(df_sources)
log.info("Loaded %d sources from %s", total_sources, INPUT_CSV)
print(f"Loaded {total_sources} sources\n")

# ── Accumulators ──
all_rows = []  # sentence-level
qc_rows = []  # one per document
exclusion_rows = []
failure_rows = []

processed = 0
excluded = 0
failed = 0

for idx, src in df_sources.iterrows():
    doc_num = idx + 1
    print(f"[{doc_num}/{total_sources}] {src['title'][:75]}…", end="  ")

    result = process_one_source(src.to_dict())
    document_id = make_document_id(result["url"])

    # ── Excluded ──
    if result["status"] == "excluded":
        excluded += 1
        exclusion_rows.append(
            {
                "url": result["url"],
                "title": result["title"],
                "category": result["category"],
                "source_type": result["source_type"],
                "page_count": result["page_count"],
                "reason_for_exclusion": result["exclusion_reason"],
            }
        )
        qc_rows.append(
            {
                "document_id": document_id,
                "title": result["title"],
                "url": result["url"],
                "category": result["category"],
                "source_type": result["source_type"],
                "page_count": result["page_count"],
                "extraction_status": "excluded",
                "exclusion_status": "excluded",
                "total_sentences": 0,
                "equity_sentences": 0,
                "notes": result["exclusion_reason"],
            }
        )
        print(f"EXCLUDED — {result['exclusion_reason']}")
        continue

    # ── Failed ──
    if result["status"] in ("failed", "fetch_failed"):
        failed += 1
        failure_rows.append(
            {
                "url": result["url"],
                "title": result["title"],
                "category": result["category"],
                "source_type": result["source_type"],
                "error": result["notes"],
            }
        )
        qc_rows.append(
            {
                "document_id": document_id,
                "title": result["title"],
                "url": result["url"],
                "category": result["category"],
                "source_type": result["source_type"],
                "page_count": result["page_count"],
                "extraction_status": result["status"],
                "exclusion_status": "failed",
                "total_sentences": 0,
                "equity_sentences": 0,
                "notes": result["notes"],
            }
        )
        print(f"FAILED — {result['notes'][:80]}")
        continue

    # ── Success: build sentence rows ──
    processed += 1
    sentences = result["sentences"]
    subtype = classify_subtype(
        result["title"], result["category"], result["raw_text_sample"]
    )

    equity_count = 0
    for si, sent_text in enumerate(sentences):
        sentence_id = f"{document_id}_s{si:05d}"
        features = compute_features(sent_text)

        prev_sent = sentences[si - 1] if si > 0 else ""
        next_sent = sentences[si + 1] if si < len(sentences) - 1 else ""

        all_rows.append(
            {
                "document_id": document_id,
                "sentence_id": sentence_id,
                "sentence_index_within_document": si,
                "sentence_text": sent_text,
                "category": result["category"],
                "title": result["title"],
                "source_label": result["source_label"],
                "url": result["url"],
                "source_type": result["source_type"],
                "page_count": result["page_count"],
                "document_subtype": subtype,
                "prev_sentence": prev_sent,
                "next_sentence": next_sent,
                **features,
            }
        )
        if (
            features["contains_equity"]
            or features["contains_equities"]
            or features["contains_health_equity"]
        ):
            equity_count += 1

    qc_rows.append(
        {
            "document_id": document_id,
            "title": result["title"],
            "url": result["url"],
            "category": result["category"],
            "source_type": result["source_type"],
            "page_count": result["page_count"],
            "extraction_status": "success",
            "exclusion_status": "included",
            "total_sentences": len(sentences),
            "equity_sentences": equity_count,
            "notes": "",
        }
    )
    print(f"OK — {len(sentences)} sentences ({equity_count} equity)")

    time.sleep(0.5)

print(f"\n{'='*60}")
print(f"Processing complete.")
print(f"  Processed : {processed}")
print(f"  Excluded  : {excluded}")
print(f"  Failed    : {failed}")
# Out:
# 2026-04-17 06:45:25,837  INFO      Loaded 221 sources from ../01_data/validated_dataset.csv
# Loaded 221 sources
#
# [1/221] Developing Health Equity Measures…  OK — 808 sentences (184 equity)
# [2/221] HHS Action Plan to Reduce Racial and Ethnic Health Disparities…  OK — 518 sentences (21 equity)
# [3/221] Agency Program, Activity, and Policy Highlights to Advance Health Equity an…  OK — 830 sentences (34 equity)
# [4/221] Advancing Equity through Quantitative Analysis…  EXCLUDED — page_count=14 < 20
# [5/221] 2023 Capacity Assessment Update…  OK — 272 sentences (5 equity)
# [6/221] Landscape of Area-Level Deprivation Measures and Other Approaches to Accoun…  OK — 1597 sentences (8 equity)
# [7/221] Building Data Capacity for Patient-Centered Outcomes Research to Address CO…  OK — 430 sentences (2 equity)
# [8/221] Health Equity Guide…  EXCLUDED — page_count=7 < 20
# [9/221] Focusing on Health Equity…  2026-04-17 06:46:29,109  WARNING   Attempt 1/2 failed for https://stacks.cdc.gov/view/cdc/126226/cdc_126226_DS1.pdf: 403 Client Error: Forbidden for url: https://stacks.cdc.gov/view/cdc/126226/cdc_126226_DS1.pdf
# 2026-04-17 06:46:34,206  WARNING   Attempt 2/2 failed for https://stacks.cdc.gov/view/cdc/126226/cdc_126226_DS1.pdf: 403 Client Error: Forbidden for url: https://stacks.cdc.gov/view/cdc/126226/cdc_126226_DS1.pdf
# FAILED — All 2 attempts failed for https://stacks.cdc.gov/view/cdc/126226/cdc_126226_DS1.
# [10/221] Promoting Health Equity: A Resource to Help Communities Address Social Dete…  2026-04-17 06:46:34,354  WARNING   Attempt 1/2 failed for https://stacks.cdc.gov/view/cdc/11130/cdc_11130_DS1.pdf: 403 Client Error: Forbidden for url: https://stacks.cdc.gov/view/cdc/11130/cdc_11130_DS1.pdf
# 2026-04-17 06:46:39,464  WARNING   Attempt 2/2 failed for https://stacks.cdc.gov/view/cdc/11130/cdc_11130_DS1.pdf: 403 Client Error: Forbidden for url: https://stacks.cdc.gov/view/cdc/11130/cdc_11130_DS1.pdf
# FAILED — All 2 attempts failed for https://stacks.cdc.gov/view/cdc/11130/cdc_11130_DS1.pd
# [11/221] CDC's Health Equity Guiding Principles for Inclusive Communication…  EXCLUDED — page_count=2 < 20
# [12/221] Working Toward Health Equity…  EXCLUDED — page_count=2 < 20
# [13/221] Improving Social Determinants of Health --- Getting Further Faster Evaluati…  EXCLUDED — page_count=11 < 20
# [14/221] CDC COVID-19 Response Health Equity Strategy…  EXCLUDED — page_count=5 < 20
# [15/221] CMS Framework for Health Equity 2022--2032…  OK — 543 sentences (114 equity)
# [16/221] Health Equity Data Book…  OK — 263 sentences (4 equity)
# [17/221] Resource of Health Equity-Related Data Definitions, Standards, Stratificati…  EXCLUDED — page_count=13 < 20
# [18/221] Improving Data to Advance Health Equity Solutions…  OK — 697 sentences (154 equity)
# [19/221] Assessing Equity to Drive Health Care Improvements…  OK — 351 sentences (38 equity)
# [20/221] States Advancing All-Payer Health Equity Approaches and Development (AHEAD)…  EXCLUDED — page_count=3 < 20
# [21/221] Health Equity Report 2019--2020…  2026-04-17 06:47:12,993  WARNING   Attempt 1/2 failed for https://www.hrsa.gov/sites/default/files/hrsa/about/news/hrsa-health-equity-report.pdf: 403 Client Error: Forbidden for url: https://www.hrsa.gov/sites/default/files/hrsa/about/news/hrsa-health-equity-report.pdf
# 2026-04-17 06:47:18,099  WARNING   Attempt 2/2 failed for https://www.hrsa.gov/sites/default/files/hrsa/about/news/hrsa-health-equity-report.pdf: 403 Client Error: Forbidden for url: https://www.hrsa.gov/sites/default/files/hrsa/about/news/hrsa-health-equity-report.pdf
# FAILED — All 2 attempts failed for https://www.hrsa.gov/sites/default/files/hrsa/about/ne
# [22/221] Paving the Way to Equity: A Progress Report (2015--2021)…  OK — 544 sentences (103 equity)
# [23/221] Health Equity and Health Disparities Environmental Scan…  OK — 724 sentences (277 equity)
# [24/221] The Role of Law and Policy in Achieving Health Equity and Attaining Our Hea…  OK — 42 sentences (26 equity)
# [25/221] Implementation of Healthy People 2030: Recommendations for Implementation a…  OK — 296 sentences (13 equity)
# [26/221] CMS Framework for Advancing Health Care in Rural, Tribal, and Geographicall…  EXCLUDED — page_count=16 < 20
# [27/221] Advancing Health Equity in Rural, Tribal, and Geographically Isolated Commu…  OK — 572 sentences (53 equity)
# [28/221] National CLAS Standards…  OK — 15 sentences (0 equity)
# [29/221] National Healthcare Quality and Disparities Report…  FAILED — No meaningful text extracted
# [30/221] Healthy People 2030: Health Equity in Healthy People 2030…  OK — 12 sentences (0 equity)
# [31/221] SAMHSA Behavioral Health Equity Framework…  2026-04-17 06:47:50,143  WARNING   Attempt 1/2 failed for https://www.samhsa.gov/behavioral-health-equity: 404 Client Error: Not Found for url: https://www.samhsa.gov/behavioral-health-equity
# 2026-04-17 06:47:55,393  WARNING   Attempt 2/2 failed for https://www.samhsa.gov/behavioral-health-equity: 404 Client Error: Not Found for url: https://www.samhsa.gov/behavioral-health-equity
# FAILED — All 2 attempts failed for https://www.samhsa.gov/behavioral-health-equity
# [32/221] IHS Disparities Fact Sheet…  OK — 19 sentences (0 equity)
# [33/221] Health disparities and health equity: concepts and measurement…  OK — 8 sentences (4 equity)
# [34/221] Health disparities and health equity: the issue is justice…  OK — 5 sentences (0 equity)
# [35/221] Toward a fourth generation of disparities research to achieve health equity…  OK — 6 sentences (1 equity)
# [36/221] How Policy Improves Health…  OK — 6 sentences (5 equity)
# [37/221] Policy Approaches to Advancing Health Equity…  OK — 7 sentences (4 equity)
# [38/221] Integrating Health Equity Into Practice and Policy…  OK — 4 sentences (3 equity)
# [39/221] Closing The Gaps In Health Care Disparities, Interventions, And Research…  OK — 5 sentences (2 equity)
# [40/221] The Importance of Policy Change for Addressing Public Health Problems…  OK — 1 sentences (0 equity)
# [41/221] Making Strides Toward Health Equity: The Experiences of Public Health Depar…  OK — 11 sentences (6 equity)
# [42/221] Reducing Health Disparities to Promote Health Equity through Health Policy …  OK — 4 sentences (1 equity)
# [43/221] Strategies for Achieving Health Equity: Concern about the Whole and Concern…  OK — 6 sentences (6 equity)
# [44/221] Addressing Health Equity in Public Health Practice…  OK — 5 sentences (4 equity)
# [45/221] The Potential and Realized Impact of the Affordable Care Act on Health Equi…  OK — 8 sentences (3 equity)
# [46/221] Race, Racism, and the Policy of 21st Century Medicine…  OK — 4 sentences (1 equity)
# [47/221] How the Trump Administration's Pandemic Health Care Policies Endanger Racia…  FAILED — No meaningful text extracted
# [48/221] How Do We Define and Measure Health Equity? The State of Current Practice a…  OK — 12 sentences (10 equity)
# [49/221] Medicaid can and should play an active role in advancing health equity…  2026-04-17 06:48:10,973  WARNING   Attempt 1/2 failed for https://onlinelibrary.wiley.com/doi/10.1111/1475-6773.14069: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# 2026-04-17 06:48:16,072  WARNING   Attempt 2/2 failed for https://onlinelibrary.wiley.com/doi/10.1111/1475-6773.14069: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/10.1111/1475-6773.14069
# FAILED — All 2 attempts failed for https://onlinelibrary.wiley.com/doi/10.1111/1475-6773.
# [50/221] How Much Does the US Public Value Equity in Health? A Systematic Review…  OK — 13 sentences (6 equity)
# [51/221] Advancing health equity through partnerships of state Medicaid agencies, MC…  OK — 14 sentences (9 equity)
# [52/221] Understanding Health Equity in Public Health Practice in the United States…  OK — 12 sentences (7 equity)
# [53/221] Mechanisms to enhance racial equity in health care…  OK — 10 sentences (3 equity)
# [54/221] Health equity is not possible without addressing disparities…  OK — 10 sentences (7 equity)
# [55/221] Health equity: A concept analysis…  OK — 8 sentences (8 equity)
# [56/221] Perspectives on Health Equity and Social Determinants of Health…  OK — 10 sentences (3 equity)
# [57/221] Race, Healthcare, and Health Disparities: A Critical Review and Recommendat…  OK — 7 sentences (3 equity)
# [58/221] Health Equity and Access to Health Care as a Social Determinant of Health…  OK — 5 sentences (3 equity)
# [59/221] Health Care Policy and Disparities in Health…  OK — 6 sentences (1 equity)
# [60/221] Health equity: access to quality services and caring for all people…  OK — 7 sentences (3 equity)
# [61/221] Advancing health equity through social care interventions…  OK — 7 sentences (6 equity)
# [62/221] The Role of Health Policy in Improving Health Outcomes and Health Equity…  OK — 7 sentences (1 equity)
# [63/221] Did the Affordable Care Act Promote Racial Equity in Pregnancy-Related Heal…  OK — 9 sentences (2 equity)
# [64/221] Implementation and early effects of Medicaid policy interventions to advanc…  OK — 11 sentences (5 equity)
# [65/221] Strategies and indicators to integrate health equity in health service and …  OK — 23 sentences (14 equity)
# [66/221] A Scoping Review of Health Equity Interventions in Collaboration with Publi…  OK — 10 sentences (5 equity)
# [67/221] Social determinants of health and health equity policy research: exploring …  OK — 13 sentences (2 equity)
# [68/221] Six Principles for Embedding Health Equity Language in Policy-Focused Resea…  OK — 10 sentences (5 equity)
# [69/221] Barriers to health equity in the United States of America…  OK — 6 sentences (4 equity)
# [70/221] How is health equity considered in policy evaluations employing quasi-exper…  OK — 12 sentences (6 equity)
# [71/221] The US Medicaid Program: Coverage, Financing, Reforms, and Implications for…  OK — 14 sentences (3 equity)
# [72/221] Conceptual approaches in combating health inequity: A scoping review protoc…  OK — 9 sentences (4 equity)
# [73/221] Methods used to conceptualize dimensions of health equity impacts of public…  OK — 20 sentences (10 equity)
# [74/221] The health equity measurement framework: a comprehensive model to measure s…  OK — 11 sentences (9 equity)
# [75/221] The Health Equity Framework: A Science- and Justice-Based Model for Public …  OK — 10 sentences (5 equity)
# [76/221] Advancing Health Equity in Health Care Coverage: A Public-Private Partnersh…  OK — 5 sentences (0 equity)
# [77/221] Using Participatory Implementation Science to Advance Health Equity…  OK — 6 sentences (2 equity)
# [78/221] A conceptual framework for evaluating health equity promotion within commun…  OK — 7 sentences (6 equity)
# [79/221] Addressing health equity during design and implementation of health system …  OK — 16 sentences (14 equity)
# [80/221] Health Equity in Public Health: Clarifying our Commitment…  2026-04-17 06:48:46,703  WARNING   Attempt 1/2 failed for https://academic.oup.com/phe/article-abstract/8/2/173/2362531: 403 Client Error: Forbidden for url: https://academic.oup.com/phe/article-abstract/8/2/173/2362531
# 2026-04-17 06:48:51,795  WARNING   Attempt 2/2 failed for https://academic.oup.com/phe/article-abstract/8/2/173/2362531: 403 Client Error: Forbidden for url: https://academic.oup.com/phe/article-abstract/8/2/173/2362531
# FAILED — All 2 attempts failed for https://academic.oup.com/phe/article-abstract/8/2/173/
# [81/221] (Re)Engaging the Normative in Public Health Discourse and Practice? The Cas…  2026-04-17 06:48:51,880  WARNING   Attempt 1/2 failed for https://academic.oup.com/phe/article-abstract/13/3/247/5874652: 403 Client Error: Forbidden for url: https://academic.oup.com/phe/article-abstract/13/3/247/5874652
# 2026-04-17 06:48:56,967  WARNING   Attempt 2/2 failed for https://academic.oup.com/phe/article-abstract/13/3/247/5874652: 403 Client Error: Forbidden for url: https://academic.oup.com/phe/article-abstract/13/3/247/5874652
# FAILED — All 2 attempts failed for https://academic.oup.com/phe/article-abstract/13/3/247
# [82/221] Food Sovereignty, Food Security and Health Equity: A Meta-Narrative Mapping…  2026-04-17 06:48:57,048  WARNING   Attempt 1/2 failed for https://academic.oup.com/heapol/article-abstract/30/8/1078/555203: 403 Client Error: Forbidden for url: https://academic.oup.com/heapol/article-abstract/30/8/1078/555203
# 2026-04-17 06:49:02,135  WARNING   Attempt 2/2 failed for https://academic.oup.com/heapol/article-abstract/30/8/1078/555203: 403 Client Error: Forbidden for url: https://academic.oup.com/heapol/article-abstract/30/8/1078/555203
# FAILED — All 2 attempts failed for https://academic.oup.com/heapol/article-abstract/30/8/
# [83/221] Possible Connections Between Health Equity and Primary Health Care: a Scopi…  OK — 2 sentences (1 equity)
# [84/221] Sentinels of Inequity: Examining Policy Requirements for Equity-Oriented Pr…  OK — 1 sentences (1 equity)
# [85/221] A Tool to Assess Alignment Between Knowledge and Action for Health Equity…  OK — 2 sentences (1 equity)
# [86/221] "The Health Equity Curse": Ethical Tensions in Promoting Health Equity…  OK — 2 sentences (1 equity)
# [87/221] A Health Equity Framework for the US Preventive Services Task Force…  2026-04-17 06:49:10,265  WARNING   Attempt 1/2 failed for https://jamanetwork.com/journals/jamanetworkopen/fullarticle/2815866: 403 Client Error: Forbidden for url: https://jamanetwork.com/journals/jamanetworkopen/fullarticle/2815866
# 2026-04-17 06:49:15,361  WARNING   Attempt 2/2 failed for https://jamanetwork.com/journals/jamanetworkopen/fullarticle/2815866: 403 Client Error: Forbidden for url: https://jamanetwork.com/journals/jamanetworkopen/fullarticle/2815866
# FAILED — All 2 attempts failed for https://jamanetwork.com/journals/jamanetworkopen/fulla
# [88/221] A Road Map for Population Health and Health Equity Research…  2026-04-17 06:49:15,446  WARNING   Attempt 1/2 failed for https://jamanetwork.com/journals/jamapediatrics/article-abstract/2819321: 403 Client Error: Forbidden for url: https://jamanetwork.com/journals/jamapediatrics/article-abstract/2819321
# 2026-04-17 06:49:20,537  WARNING   Attempt 2/2 failed for https://jamanetwork.com/journals/jamapediatrics/article-abstract/2819321: 403 Client Error: Forbidden for url: https://jamanetwork.com/journals/jamapediatrics/article-abstract/2819321
# FAILED — All 2 attempts failed for https://jamanetwork.com/journals/jamapediatrics/articl
# [89/221] The US Health Equity Crisis --- An Economic Case for a Moral Imperative?…  2026-04-17 06:49:20,623  WARNING   Attempt 1/2 failed for https://jamanetwork.com/journals/jama/article-abstract/2804847: 403 Client Error: Forbidden for url: https://jamanetwork.com/journals/jama/article-abstract/2804847
# 2026-04-17 06:49:25,726  WARNING   Attempt 2/2 failed for https://jamanetwork.com/journals/jama/article-abstract/2804847: 403 Client Error: Forbidden for url: https://jamanetwork.com/journals/jama/article-abstract/2804847
# FAILED — All 2 attempts failed for https://jamanetwork.com/journals/jama/article-abstract
# [90/221] Advocacy for Health Equity: A Synthesis Review…  OK — 25 sentences (6 equity)
# [91/221] Advancing a Health Equity Agenda Across Multiple Policy Domains: a Qualitat…  2026-04-17 06:49:27,654  WARNING   Attempt 1/2 failed for https://bmjopen.bmj.com/content/10/11/e040180: 403 Client Error: Forbidden for url: https://bmjopen.bmj.com/content/10/11/e040180
# 2026-04-17 06:49:32,752  WARNING   Attempt 2/2 failed for https://bmjopen.bmj.com/content/10/11/e040180: 403 Client Error: Forbidden for url: https://bmjopen.bmj.com/content/10/11/e040180
# FAILED — All 2 attempts failed for https://bmjopen.bmj.com/content/10/11/e040180
# [92/221] Social Determinants of Health Inequalities…  OK — 7 sentences (0 equity)
# [93/221] Unequal Treatment: Confronting Racial and Ethnic Disparities in Health Care…  OK — 9 sentences (0 equity)
# [94/221] What Are Health Disparities and Health Equity? We Need to Be Clear…  OK — 8 sentences (0 equity)
# [95/221] Structural Racism and Health Inequities in the USA: Evidence and Interventi…  OK — 5 sentences (2 equity)
# [96/221] Structural Racism and Health Inequities…  FAILED — No meaningful text extracted
# [97/221] Creating the Healthiest Nation: Advancing Health Equity…  OK — 8 sentences (0 equity)
# [98/221] Achieving Health Equity: Closing the Gaps in Health Care Disparities, Inter…  OK — 9 sentences (0 equity)
# [99/221] Racism and Health: Evidence and Needed Research…  OK — 8 sentences (0 equity)
# [100/221] Health Equity --- Are We Finally on the Edge of a New Frontier?…  FAILED — No meaningful text extracted
# [101/221] The Concepts and Measurement of Race and Ethnicity in Health Sciences Resea…  OK — 11 sentences (0 equity)
# [102/221] Moving Upstream to Reduce Racial Inequities in Child Health…  OK — 12 sentences (0 equity)
# [103/221] Health Inequity and the Effects of COVID-19…  OK — 12 sentences (0 equity)
# [104/221] COVID-19 and Racial/Ethnic Disparities…  OK — 16 sentences (0 equity)
# [105/221] Racial and Ethnic Disparities in Adult Vaccination…  OK — 22 sentences (0 equity)
# [106/221] The Weathering Hypothesis and the Health of African-American Women and Infa…  FAILED — No meaningful text extracted
# [107/221] Achieving Equity in an Evolving Healthcare System: Opportunities and Challe…  OK — 11 sentences (0 equity)
# [108/221] Principles of Health Equity Science for Public Health Action Correct…  OK — 1 sentences (1 equity)
# [109/221] Implicit Bias in Health Care Professionals: A Systematic Review…  FAILED — No meaningful text extracted
# [110/221] Inequity in Quality of Care for Patients with Diabetes…  FAILED — No meaningful text extracted
# [111/221] Social Determinants of Health and Equity in the United States…  FAILED — No meaningful text extracted
# [112/221] Equity and Excellence in American Higher Education: University-Community He…  FAILED — No meaningful text extracted
# [113/221] Addressing the Social Determinants of Health: The Urban Areas Health Educat…  FAILED — No meaningful text extracted
# [114/221] The Quintuple Aim for Health Care Improvement: A New Imperative to Advance …  FAILED — No meaningful text extracted
# [115/221] An Equity Lens on Intellectual and Developmental Disabilities Research…  FAILED — No meaningful text extracted
# [116/221] Intersectionality and Health: An Introduction…  FAILED — No meaningful text extracted
# [117/221] Defining Health Equity: A Modern US Perspective…  FAILED — No meaningful text extracted
# [118/221] From Health Literacy to Health Equity: A Discourse Analysis of Chronic Dise…  FAILED — No meaningful text extracted
# [119/221] The Role of Public Health in Addressing Racial and Ethnic Disparities in Me…  FAILED — No meaningful text extracted
# [120/221] Confronting Health Inequities Among Indigenous Peoples…  FAILED — No meaningful text extracted
# [121/221] Healthcare Disparities in Pediatrics…  FAILED — No meaningful text extracted
# [122/221] Social Determinants of Health Equity…  FAILED — No meaningful text extracted
# [123/221] Progress in Achieving Health Equity Requires Attention to Root Causes…  FAILED — No meaningful text extracted
# [124/221] Discrimination, Mental Health, and Suicidal Ideation Among LGBTQ People of …  FAILED — No meaningful text extracted
# [125/221] Rural-Urban Disparities in Health Care in the United States…  FAILED — No meaningful text extracted
# [126/221] Maternal Mortality and Morbidity in the United States: Where Are We Now?…  FAILED — No meaningful text extracted
# [127/221] The National Institute on Minority Health and Health Disparities Research F…  FAILED — No meaningful text extracted
# [128/221] Addressing Social Determinants of Health in Primary Care…  FAILED — No meaningful text extracted
# [129/221] Community Health Workers as a Strategy to Address Health Inequities…  OK — 10 sentences (0 equity)
# [130/221] Health Disparities in Chronic Kidney Disease…  OK — 9 sentences (0 equity)
# [131/221] Measuring Health Disparities, Health Inequities, and Social Determinants of…  OK — 9 sentences (0 equity)
# [132/221] Place Matters: Neighborhoods and Health…  OK — 5 sentences (0 equity)
# [133/221] Health Equity Plan…  OK — 309 sentences (61 equity)
# [134/221] Health Equity Guide for Public Health Practitioners and Partners (2nd ed.)…  EXCLUDED — page_count=220 > 150
# [135/221] HEIA Implementation Guide…  OK — 388 sentences (23 equity)
# [136/221] Racial and Ethnic Health Disparities in North Carolina…  OK — 287 sentences (32 equity)
# [137/221] Health Equity Plan…  OK — 765 sentences (349 equity)
# [138/221] Health Equity Strategic Plan…  OK — 775 sentences (240 equity)
# [139/221] Community Health Workers at Scale in New York City…  OK — 266 sentences (12 equity)
# [140/221] Regional Health Equity Plan FY23-24…  OK — 263 sentences (67 equity)
# [141/221] Health Equity Plan…  2026-04-17 06:50:42,261  WARNING   Attempt 1/2 failed for https://www.clatsopcounty.gov/media/50016: 404 Client Error: Not Found for url: https://www.clatsopcounty.gov/media/50016
# 2026-04-17 06:50:47,593  WARNING   Attempt 2/2 failed for https://www.clatsopcounty.gov/media/50016: 404 Client Error: Not Found for url: https://www.clatsopcounty.gov/media/50016
# FAILED — All 2 attempts failed for https://www.clatsopcounty.gov/media/50016
# [142/221] The State of Health Equity in Pennsylvania…  OK — 725 sentences (78 equity)
# [143/221] White paper on the state of health equity measurement…  OK — 511 sentences (154 equity)
# [144/221] A Vision of Health Equity & the Public Health System…  EXCLUDED — page_count=6 < 20
# [145/221] Arizona Health Equity Stakeholder Strategies…  OK — 349 sentences (35 equity)
# [146/221] Health Equity Review Planning Tool…  EXCLUDED — page_count=14 < 20
# [147/221] Nevada Health Equity Action Plan (HEAP)…  OK — 1035 sentences (224 equity)
# [148/221] 2022 Annual Report…  OK — 231 sentences (48 equity)
# [149/221] 2026 State Health Improvement Plan Update…  OK — 1132 sentences (94 equity)
# [150/221] Advancing health equity: Key questions for assessing policy, systems, and e…  EXCLUDED — page_count=3 < 20
# [151/221] Advancing Health Equity in Minnesota: Executive Summary…  EXCLUDED — page_count=7 < 20
# [152/221] Health Equity Data Analysis…  2026-04-17 06:51:48,338  WARNING   Attempt 1/2 failed for https://assets.ramseycountymn.gov/files/migrated-files/HEDA_10.12.17.pdf: 404 Client Error: Not Found for url: https://assets.ramseycountymn.gov/files/migrated-files/HEDA_10.12.17.pdf
# 2026-04-17 06:51:53,446  WARNING   Attempt 2/2 failed for https://assets.ramseycountymn.gov/files/migrated-files/HEDA_10.12.17.pdf: 404 Client Error: Not Found for url: https://assets.ramseycountymn.gov/files/migrated-files/HEDA_10.12.17.pdf
# FAILED — All 2 attempts failed for https://assets.ramseycountymn.gov/files/migrated-files
# [153/221] Portrait of Promise: The California Statewide Plan to Promote Health and Me…  2026-04-17 06:51:53,709  WARNING   Attempt 1/2 failed for https://www.cdph.ca.gov/Programs/OHE/CDPH%20Document%20Library/Accessible-CDPH_OHE_Disparity_Report_Race_Equity.pdf: HTTPSConnectionPool(host='www.cdph.ca.gov', port=443): Max retries exceeded with url: /Programs/OHE/CDPH%20Document%20Library/Accessible-CDPH_OHE_Disparity_Report_Race_Equity.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1010)')))
# 2026-04-17 06:51:58,800  WARNING   Attempt 2/2 failed for https://www.cdph.ca.gov/Programs/OHE/CDPH%20Document%20Library/Accessible-CDPH_OHE_Disparity_Report_Race_Equity.pdf: HTTPSConnectionPool(host='www.cdph.ca.gov', port=443): Max retries exceeded with url: /Programs/OHE/CDPH%20Document%20Library/Accessible-CDPH_OHE_Disparity_Report_Race_Equity.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1010)')))
# FAILED — All 2 attempts failed for https://www.cdph.ca.gov/Programs/OHE/CDPH%20Document%2
# [154/221] A Blueprint for Health Equity: Health Equity Task Force Final Report…  OK — 1325 sentences (206 equity)
# [155/221] Oregon Health Equity Review…  2026-04-17 06:52:22,478  WARNING   Attempt 1/2 failed for https://sharedsystems.dhsoha.state.or.us/DHSForms/Served/le-683051.pdf: HTTPSConnectionPool(host='sharedsystems.dhsoha.state.or.us', port=443): Max retries exceeded with url: /DHSForms/Served/le-683051.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1010)')))
# 2026-04-17 06:52:27,705  WARNING   Attempt 2/2 failed for https://sharedsystems.dhsoha.state.or.us/DHSForms/Served/le-683051.pdf: HTTPSConnectionPool(host='sharedsystems.dhsoha.state.or.us', port=443): Max retries exceeded with url: /DHSForms/Served/le-683051.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1010)')))
# FAILED — All 2 attempts failed for https://sharedsystems.dhsoha.state.or.us/DHSForms/Serv
# [156/221] Illinois Health Equity Plan…  OK — 927 sentences (67 equity)
# [157/221] Michigan Health Equity Roadmap…  OK — 1058 sentences (204 equity)
# [158/221] New Jersey Health Equity Strategy…  OK — 184 sentences (14 equity)
# [159/221] LA County Health Equity Plan…  OK — 515 sentences (91 equity)
# [160/221] King County Equity and Social Justice Strategic Plan…  OK — 807 sentences (171 equity)
# [161/221] Wisconsin Health Disparities Report…  OK — 240 sentences (19 equity)
# [162/221] Race, Inequality, and Health…  EXCLUDED — page_count=19 < 20
# [163/221] Disparities in Health and Health Care: Five Key Questions and Answers…  EXCLUDED — page_count=13 < 20
# [164/221] Beyond Health Care: The Role of Social Determinants in Promoting Health and…  EXCLUDED — page_count=13 < 20
# [165/221] Racial and Ethnic Health Inequities and Medicare…  OK — 219 sentences (5 equity)
# [166/221] Key Themes from a Roundtable Discussion of Health Care and Health Equity in…  2026-04-17 06:53:44,428  WARNING   Attempt 1/2 failed for https://www.kff.org/wp-content/uploads/2014/06/8606-discussion-of-health-care-and-health-equity-in-the-south.pdf: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# EXCLUDED — page_count=9 < 20
# [167/221] Advancing Racial Equity in U.S. Health Care…  OK — 239 sentences (16 equity)
# [168/221] Achieving Racial and Ethnic Equity in U.S. Health Care…  OK — 232 sentences (16 equity)
# [169/221] Advancing Racial Equity in Health Care…  EXCLUDED — page_count=2 < 20
# [170/221] Mirror, Mirror 2024: A Portrait of the Failing U.S. Health System…  OK — 635 sentences (50 equity)
# [171/221] Accelerating Progress Toward Health Care Equity…  EXCLUDED — page_count=8 < 20
# [172/221] Envisioning a New Health System Rooted in Equity…  OK — 742 sentences (54 equity)
# [173/221] Using Race and Ethnicity Data to Advance Health Equity…  OK — 380 sentences (91 equity)
# [174/221] Guide to Equity in Behavioral Health Care…  EXCLUDED — page_count=12 < 20
# [175/221] Collection of Race and Ethnicity Data for Use by Health Plans to Advance He…  OK — 604 sentences (60 equity)
# [176/221] Guide to Equity for the Uninsured…  EXCLUDED — page_count=8 < 20
# [177/221] Guide to Equity in Medicaid…  EXCLUDED — page_count=9 < 20
# [178/221] A Framework for Advancing Health Equity and Value…  OK — 797 sentences (158 equity)
# [179/221] A National Priority Agenda to Advance Health Equity…  OK — 269 sentences (75 equity)
# [180/221] Accelerating Health Equity by Measuring and Paying for Results…  EXCLUDED — page_count=14 < 20
# [181/221] Advancing Equity in 2023: Federal Policy Priorities to Advance Health Equit…  EXCLUDED — page_count=11 < 20
# [182/221] Advancing Health Equity Through Community Health Workers and Patient/Peer P…  OK — 368 sentences (44 equity)
# [183/221] A Call to Action for Health Equity Leaders…  EXCLUDED — page_count=8 < 20
# [184/221] Making Progress Toward Health Equity…  EXCLUDED — page_count=14 < 20
# [185/221] What Is Health Equity? And What Difference Does a Definition Make?…  OK — 31 sentences (19 equity)
# [186/221] From Vision to Action: Measures to Mobilize a Culture of Health…  OK — 970 sentences (13 equity)
# [187/221] Communities in Action: Pathways to Health…  OK — 23 sentences (5 equity)
# [188/221] Charting a Course for an Equity-Centered Data System…  OK — 25 sentences (11 equity)
# [189/221] Equity of Care Toolkit…  OK — 4 sentences (2 equity)
# [190/221] Achieving Health Equity: A Guide for Health Care Organizations…  OK — 18 sentences (9 equity)
# [191/221] State of Black America (annual report)…  OK — 24 sentences (2 equity)
# [192/221] Time for justice: Tackling race inequalities in health and housing…  OK — 6 sentences (1 equity)
# [193/221] How white scholars are colonizing research on health disparities…  OK — 262 sentences (36 equity)
# [194/221] Black Americans Still Suffer Worse Health. Here's Why That's Hard to Fix.…  OK — 2 sentences (0 equity)
# [195/221] Study Reveals Staggering Toll of Being Black in America: 1.6M Excess Deaths…  OK — 2 sentences (0 equity)
# [196/221] Racism Derails Black Men's Health, Even as Education Levels Rise…  OK — 1 sentences (0 equity)
# [197/221] Listen: NPR and KFF Health News Explore How Racism and Violence Hurt Health…  OK — 1 sentences (0 equity)
# [198/221] The Growing Inequality in Life Expectancy Among Americans…  OK — 1 sentences (0 equity)
# [199/221] Achieving an equitable national health system for America…  OK — 3 sentences (1 equity)
# [200/221] Re-balancing medical and social spending to promote health…  OK — 3 sentences (1 equity)
# [201/221] Promote health equity by taxing sugary drinks and doubling support for comm…  OK — 4 sentences (1 equity)
# [202/221] Health plans need to address health inequities as part of their core work…  OK — 1 sentences (0 equity)
# [203/221] In defense of not treating everyone the same…  FAILED — No meaningful text extracted
# [204/221] Mississippi Lacks Black Doctors, Even as Lawmakers Move Against Diversity P…  OK — 1 sentences (0 equity)
# [205/221] Health Insurance Benefits Should Be Equitable, Not Necessarily Equal…  2026-04-17 07:04:44,512  WARNING   Attempt 1/2 failed for https://healthaffairs.org/do/10.1377/hblog20170522.060211/full: 403 Client Error: Forbidden for url: https://healthaffairs.org/do/10.1377/hblog20170522.060211/full
# 2026-04-17 07:04:49,656  WARNING   Attempt 2/2 failed for https://healthaffairs.org/do/10.1377/hblog20170522.060211/full: 403 Client Error: Forbidden for url: https://healthaffairs.org/do/10.1377/hblog20170522.060211/full
# FAILED — All 2 attempts failed for https://healthaffairs.org/do/10.1377/hblog20170522.060
# [206/221] Reimagining Rural Health Equity…  2026-04-17 07:04:49,842  WARNING   Attempt 1/2 failed for https://www.healthaffairs.org/doi/10.1377/hlthaff.2024.00036: 403 Client Error: Forbidden for url: https://www.healthaffairs.org/doi/10.1377/hlthaff.2024.00036
# 2026-04-17 07:04:54,933  WARNING   Attempt 2/2 failed for https://www.healthaffairs.org/doi/10.1377/hlthaff.2024.00036: 403 Client Error: Forbidden for url: https://www.healthaffairs.org/doi/10.1377/hlthaff.2024.00036
# FAILED — All 2 attempts failed for https://www.healthaffairs.org/doi/10.1377/hlthaff.2024
# [207/221] 5 building blocks to help achieve greater health equity…  OK — 4 sentences (1 equity)
# [208/221] Using digital health to improve health outcomes and equity…  OK — 4 sentences (0 equity)
# [209/221] Cost-effectiveness of health interventions may be perpetuating disparities …  OK — 1 sentences (0 equity)
# [210/221] Despite lack of progress on health equity, these leaders forged ahead anywa…  OK — 177 sentences (9 equity)
# [211/221] National Academies proposes reimagining health care to fix unequal treatmen…  OK — 1 sentences (0 equity)
# [212/221] Health Equity Should Be a Key Value in Value-Based Payment and Delivery Ref…  2026-04-17 07:05:00,906  WARNING   Attempt 1/2 failed for https://www.healthaffairs.org/content/forefront/health-equity-should-key-value-value-based-payment-and-delivery-reform: 403 Client Error: Forbidden for url: https://www.healthaffairs.org/content/forefront/health-equity-should-key-value-value-based-payment-and-delivery-reform
# 2026-04-17 07:05:06,017  WARNING   Attempt 2/2 failed for https://www.healthaffairs.org/content/forefront/health-equity-should-key-value-value-based-payment-and-delivery-reform: 403 Client Error: Forbidden for url: https://www.healthaffairs.org/content/forefront/health-equity-should-key-value-value-based-payment-and-delivery-reform
# FAILED — All 2 attempts failed for https://www.healthaffairs.org/content/forefront/health
# [213/221] Advancing Health Equity Through Value-Based Care: CMS Innovation Center Upd…  2026-04-17 07:05:06,106  WARNING   Attempt 1/2 failed for https://www.healthaffairs.org/do/10.1377/forefront.20240603.385559/: 403 Client Error: Forbidden for url: https://www.healthaffairs.org/do/10.1377/forefront.20240603.385559/
# 2026-04-17 07:05:11,387  WARNING   Attempt 2/2 failed for https://www.healthaffairs.org/do/10.1377/forefront.20240603.385559/: 403 Client Error: Forbidden for url: https://www.healthaffairs.org/do/10.1377/forefront.20240603.385559/
# FAILED — All 2 attempts failed for https://www.healthaffairs.org/do/10.1377/forefront.202
# [214/221] Aligning Quality Measures across CMS: The Universal Foundation…  2026-04-17 07:05:11,637  WARNING   Attempt 1/2 failed for https://www.nejm.org/doi/full/10.1056/NEJMp2215539: 403 Client Error: Forbidden for url: https://www.nejm.org/doi/full/10.1056/NEJMp2215539
# 2026-04-17 07:05:16,758  WARNING   Attempt 2/2 failed for https://www.nejm.org/doi/full/10.1056/NEJMp2215539: 403 Client Error: Forbidden for url: https://www.nejm.org/doi/full/10.1056/NEJMp2215539
# FAILED — All 2 attempts failed for https://www.nejm.org/doi/full/10.1056/NEJMp2215539
# [215/221] Navigating Health Equity in 2024: The Evolution of Accountability, Part 1…  2026-04-17 07:05:16,913  WARNING   Attempt 1/2 failed for https://www.ajmc.com/view/navigating-health-equity-in-2024-the-evolution-of-accountability-part-1: 403 Client Error: Forbidden for url: https://www.ajmc.com/view/navigating-health-equity-in-2024-the-evolution-of-accountability-part-1
# 2026-04-17 07:05:22,019  WARNING   Attempt 2/2 failed for https://www.ajmc.com/view/navigating-health-equity-in-2024-the-evolution-of-accountability-part-1: 403 Client Error: Forbidden for url: https://www.ajmc.com/view/navigating-health-equity-in-2024-the-evolution-of-accountability-part-1
# FAILED — All 2 attempts failed for https://www.ajmc.com/view/navigating-health-equity-in-
# [216/221] Dobbs, another frontline for health equity…  OK — 4 sentences (1 equity)
# [217/221] I saw the promise of diversity efforts in health care. A moment of reckonin…  OK — 1 sentences (0 equity)
# [218/221] HHS is climate washing, not addressing health care emissions…  OK — 1 sentences (0 equity)
# [219/221] Many People of Color Worry Good Health Care Is Tied to How They Look and So…  OK — 1 sentences (0 equity)
# [220/221] Women and Minorities Bear the Brunt of Medical Misdiagnosis…  OK — 1 sentences (0 equity)
# [221/221] Live from Austin, Examining Health Equity…  OK — 1 sentences (1 equity)
#
# ============================================================
# Processing complete.
#   Processed : 146
#   Excluded  : 27
#   Failed    : 48

# %% [markdown]
# ## Write all output CSVs (same folder)

# %%
# ── Write outputs to the SAME folder ─────────────────────────

# 1. Full sentence corpus
df_full = pd.DataFrame(all_rows)
df_full.to_csv(
    OUTPUT_DIR / "full_sentence_corpus.csv", index=False, encoding="utf-8-sig"
)
print(f"✓ full_sentence_corpus.csv        — {len(df_full):,} rows")

# 2. Equity subset
if not df_full.empty:
    mask = (
        df_full["contains_equity"]
        | df_full["contains_equities"]
        | df_full["contains_health_equity"]
    )
    df_equity = df_full[mask].copy()
else:
    df_equity = pd.DataFrame()
df_equity.to_csv(
    OUTPUT_DIR / "equity_sentence_subset.csv", index=False, encoding="utf-8-sig"
)
print(f"✓ equity_sentence_subset.csv      — {len(df_equity):,} rows")

# 3. QC report
df_qc = pd.DataFrame(qc_rows)
df_qc.to_csv(OUTPUT_DIR / "extraction_qc_report.csv", index=False, encoding="utf-8-sig")
print(f"✓ extraction_qc_report.csv        — {len(df_qc):,} rows")

# 4. Exclusion log
df_excl = pd.DataFrame(exclusion_rows)
df_excl.to_csv(OUTPUT_DIR / "exclusion_log.csv", index=False, encoding="utf-8-sig")
print(f"✓ exclusion_log.csv               — {len(df_excl):,} rows")

# 5. Failure log
df_fail = pd.DataFrame(failure_rows)
df_fail.to_csv(OUTPUT_DIR / "failure_log.csv", index=False, encoding="utf-8-sig")
print(f"✓ failure_log.csv                 — {len(df_fail):,} rows")
# Out:
# ✓ full_sentence_corpus.csv        — 27,292 rows
# ✓ equity_sentence_subset.csv      — 4,126 rows
# ✓ extraction_qc_report.csv        — 221 rows
# ✓ exclusion_log.csv               — 27 rows
# ✓ failure_log.csv                 — 48 rows

# %% [markdown]
# ## Summary statistics

# %%
# ── Summary ──────────────────────────────────────────────────

print("=" * 60)
print("CORPUS BUILD SUMMARY")
print("=" * 60)
print(f"Total sources:      {total_sources}")
print(f"Processed sources:  {processed}")
print(f"Excluded sources:   {excluded}")
print(f"Failed sources:     {failed}")
print("-" * 40)
print(f"Total sentences:    {len(df_full):,}")
print(f"Equity sentences:   {len(df_equity):,}")
print()

if not df_full.empty:
    print("Sentences per category:")
    for cat, cnt in df_full["category"].value_counts().items():
        print(f"  {cat:<28s} {cnt:,}")
    print()

if not df_equity.empty:
    print("Equity sentences per category:")
    for cat, cnt in df_equity["category"].value_counts().items():
        print(f"  {cat:<28s} {cnt:,}")
    print()

print("Unique documents:", df_full["document_id"].nunique() if not df_full.empty else 0)
print("=" * 60)
# Out:
# ============================================================
# CORPUS BUILD SUMMARY
# ============================================================
# Total sources:      221
# Processed sources:  146
# Excluded sources:   27
# Failed sources:     48
# ----------------------------------------
# Total sentences:    27,292
# Equity sentences:   4,126
#
# Sentences per category:
#   state_local                  12,092
#   federal_policy               8,533
#   ngo_nonprofit                5,580
#   academic                     604
#   news_commentary              483
#
# Equity sentences per category:
#   state_local                  2,189
#   federal_policy               1,036
#   ngo_nonprofit                630
#   academic                     219
#   news_commentary              52
#
# Unique documents: 146
# ============================================================

# %% [markdown]
# ## Quick preview of the corpus

# %%
# ── Preview ──────────────────────────────────────────────────
if not df_full.empty:
    print("── full_sentence_corpus.csv (first 5 rows) ──")
    display(
        df_full[
            [
                "document_id",
                "sentence_index_within_document",
                "sentence_text",
                "category",
                "contains_equity",
                "document_subtype",
            ]
        ].head()
    )

    print("\n── equity_sentence_subset.csv (first 5 rows) ──")
    display(
        df_equity[
            [
                "document_id",
                "sentence_text",
                "category",
                "contains_health_equity",
                "is_definition_sentence",
            ]
        ].head()
    )
else:
    print("No data — check failure_log.csv and exclusion_log.csv")
# Out:
# ── full_sentence_corpus.csv (first 5 rows) ──
#         document_id  sentence_index_within_document  \
# 0  doc_2d830432db58                               0
# 1  doc_2d830432db58                               1
# 2  doc_2d830432db58                               2
# 3  doc_2d830432db58                               3
# 4  doc_2d830432db58                               4
#
#                                        sentence_text        category  \
# 0  eveloping Health Equity Measures Prepared for ...  federal_policy
# 1  ASPE leads special initiatives; coordinates th...  federal_policy
# 2  Integral to this role, ASPE conducts research ...  federal_policy
# 3  Office of Health Policy The Office of Health P...  federal_policy
# 4  HP carries out this mission by conducting poli...  federal_policy
#
#    contains_equity document_subtype
# 0             True    policy_report
# 1            False    policy_report
# 2            False    policy_report
# 3            False    policy_report
# 4            False    policy_report
# ── equity_sentence_subset.csv (first 5 rows) ──
#          document_id                                      sentence_text  \
# 0   doc_2d830432db58  eveloping Health Equity Measures Prepared for ...
# 8   doc_2d830432db58  This included the recommendations that the Cen...
# 9   doc_2d830432db58  Moreover, in the ASPE commissioned report, Sys...
# 10  doc_2d830432db58  In response to this challenge, ASPE asked the ...
# 11  doc_2d830432db58  RAND identified 10 existing approaches to heal...
#
#           category  contains_health_equity  is_definition_sentence
# 0   federal_policy                    True                   False
# 8   federal_policy                    True                   False
# 9   federal_policy                    True                   False
# 10  federal_policy                    True                   False
# 11  federal_policy                    True                   False

# %% [markdown]
# ## How `document_id` controls for sentence dependency
#
# Sentences from the same document are **not independent** — they share topic, author style, and context. The `document_id` column lets you:
#
# 1. **Sample *k* sentences per document** to avoid any single long report dominating the corpus:
#    ```python
#    sampled = df_full.groupby("document_id").apply(
#        lambda g: g.sample(min(len(g), 5), random_state=42)
#    ).reset_index(drop=True)
#    ```
#
# 2. **Use `document_id` as a clustering / random-effects variable** in mixed-effects models so that standard errors account for within-document correlation.
#
# 3. **Reconstruct reading order** via `sentence_index_within_document` if you need to examine how equity framing unfolds across a document.
#
# ## Debugging tips
#
# | Symptom | Where to look | Fix |
# |---|---|---|
# | Source not in corpus | `exclusion_log.csv` | Page count outside 20–150; adjust thresholds if needed |
# | Source shows 0 sentences | `extraction_qc_report.csv` | Open the URL manually; it may be a scan-only PDF |
# | Fetch error (403/timeout) | `failure_log.csv` | Try downloading the PDF manually and adding a local-file path |
# | PubMed abstract empty | `failure_log.csv` | PubMed may have changed HTML structure; update `_extract_pubmed_abstract()` selectors |
# | Too many short fragments | Adjust `MIN_SENTENCE_CHARS` | Raise from 20 → 30 to be stricter |
